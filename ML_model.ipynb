# %%
# !pip install plotly
# !pip install hvplot
import pandas as pd
import plotly.express as px
import hvplot.pandas
from sklearn.cluster import KMeans
df = pd.DataFrame
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
file_path = "country_indicators.csv"
indic_df = pd.read_csv(file_path)
indic_df
# Out:
#       DV_phys_or_sex_partner_p  DM_age_mean  DM_age_marr_mean  \
# 0                          NaN        27.78             18.58
# 1                          NaN        28.67             20.28
# 2                          NaN        28.89             19.96
# 3                          NaN        28.52             19.80
# 4                          NaN        28.59             20.34
# ...                        ...          ...               ...
# 7365                     21.19        27.52             18.29
# 7366                     38.76        29.29             18.30
# 7367                     59.93        28.82             18.84
# 7368                     40.98        29.31             19.15
# 7369                     59.51        27.56             19.80
#
#       ED_educ_years_mean  FF_TFR  country_name
# 0                   6.29   3.575      Colombia
# 1                   6.16   2.752      Colombia
# 2                   6.40   2.546      Colombia
# 3                   6.79   2.835      Colombia
# 4                   8.79   2.447      Colombia
# ...                  ...     ...           ...
# 7365                4.35   5.318       Senegal
# 7366                3.99   4.649  Sierra Leone
# 7367                3.56   4.460  Sierra Leone
# 7368                3.88   4.970  Sierra Leone
# 7369                7.24   2.931  Sierra Leone
#
# [7370 rows x 6 columns]

# %%
indic_df = indic_df.dropna(how="any")
indic_df
# Out:
#       DV_phys_or_sex_partner_p  DM_age_mean  DM_age_marr_mean  \
# 1403                     34.24        29.43             19.32
# 1404                     43.26        29.78             20.13
# 1405                     39.72        30.05             20.48
# 1406                     49.00        29.48             19.68
# 1407                     42.68        30.10             20.89
# ...                        ...          ...               ...
# 7365                     21.19        27.52             18.29
# 7366                     38.76        29.29             18.30
# 7367                     59.93        28.82             18.84
# 7368                     40.98        29.31             19.15
# 7369                     59.51        27.56             19.80
#
#       ED_educ_years_mean  FF_TFR  country_name
# 1403                7.96   2.709      Colombia
# 1404                7.35   2.783      Colombia
# 1405                7.86   2.536      Colombia
# 1406                7.47   2.551      Colombia
# 1407                9.49   2.422      Colombia
# ...                  ...     ...           ...
# 7365                4.35   5.318       Senegal
# 7366                3.99   4.649  Sierra Leone
# 7367                3.56   4.460  Sierra Leone
# 7368                3.88   4.970  Sierra Leone
# 7369                7.24   2.931  Sierra Leone
#
# [2256 rows x 6 columns]

# %%
indic_df = indic_df.set_index('country_name')

# %%
indic_df
# Out:
#               DV_phys_or_sex_partner_p  DM_age_mean  DM_age_marr_mean  \
# country_name
# Colombia                         34.24        29.43             19.32
# Colombia                         43.26        29.78             20.13
# Colombia                         39.72        30.05             20.48
# Colombia                         49.00        29.48             19.68
# Colombia                         42.68        30.10             20.89
# ...                                ...          ...               ...
# Senegal                          21.19        27.52             18.29
# Sierra Leone                     38.76        29.29             18.30
# Sierra Leone                     59.93        28.82             18.84
# Sierra Leone                     40.98        29.31             19.15
# Sierra Leone                     59.51        27.56             19.80
#
#               ED_educ_years_mean  FF_TFR
# country_name
# Colombia                    7.96   2.709
# Colombia                    7.35   2.783
# Colombia                    7.86   2.536
# Colombia                    7.47   2.551
# Colombia                    9.49   2.422
# ...                          ...     ...
# Senegal                     4.35   5.318
# Sierra Leone                3.99   4.649
# Sierra Leone                3.56   4.460
# Sierra Leone                3.88   4.970
# Sierra Leone                7.24   2.931
#
# [2256 rows x 5 columns]

# %%
indic_scaled = StandardScaler().fit_transform(indic_df)
print(indic_scaled[0:5])
# Out:
# [[ 2.19844281e-01  3.34111827e-01 -2.77590667e-04  5.29729543e-01
#   -1.05979877e+00]
#  [ 8.34759540e-01  5.35128819e-01  5.76152046e-01  3.03458000e-01
#   -1.00865664e+00]
#  [ 5.93429161e-01  6.90199070e-01  8.25226581e-01  4.92635848e-01
#   -1.17936078e+00]
#  [ 1.22606925e+00  3.62828540e-01  2.55913359e-01  3.47970435e-01
#   -1.16899413e+00]
#  [ 7.95219534e-01  7.18915783e-01  1.11699961e+00  1.09726309e+00
#   -1.25814731e+00]]

# %%
# Initialize PCA model
pca = PCA(n_components=2)

# %%
# Get two principal components for the data
indic_pca = pca.fit_transform(indic_scaled)

# %%
# Transform PCA data to a DataFrame
indic_pca = pd.DataFrame(
    data=indic_pca, columns=["principal component 1","principal component 2"]
)
indic_pca.head()
# Out:
#    principal component 1  principal component 2
# 0               0.934209              -0.354148
# 1               1.078247              -0.809714
# 2               1.489480              -0.658216
# 3               0.909939              -1.132377
# 4               1.996145              -0.982361

# %%
# Find the best value for K
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of K values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(indic_pca)
    inertia.append(km.inertia_)

# Create the elbow curve
elbow_data = {"k": k, "inertia": inertia}
indic_df_elbow = pd.DataFrame(elbow_data)
indic_df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
# Out:
# :Curve   [k]   (inertia)

# %%
# Initialize the K-means model
model = KMeans(n_clusters=3, random_state=0)

# Fit the model
model.fit(indic_pca)

# Predict clusters
predictions = model.predict(indic_pca)

# Add the predicted class columns
indic_pca["class"] = model.labels_
indic_pca.head()
# Out:
#    principal component 1  principal component 2  class
# 0               0.934209              -0.354148      2
# 1               1.078247              -0.809714      2
# 2               1.489480              -0.658216      2
# 3               0.909939              -1.132377      2
# 4               1.996145              -0.982361      2

# %%
indic_pca.hvplot.scatter(
    x="principal component 1",
    y="principal component 2",
    hover_cols=["class"],
    by="class",
)
# Out:
# :NdOverlay   [class]
#    :Scatter   [principal component 1]   (principal component 2,class)

# %%
indic_df = indic_df.reset_index()

# %%
indic_df.shape
# Out:
# (2256, 6)

# %%
indic_pca.shape
# Out:
# (2256, 3)

# %%
print(indic_df.index.values)
# Out:
# [   0    1    2 ... 2253 2254 2255]

# %%
print(indic_pca.index.values)
# Out:
# [   0    1    2 ... 2253 2254 2255]

# %%
clustered_df = indic_df.join(indic_pca)
print(clustered_df.shape)
clustered_df
# Out:
# (2256, 9)
#       country_name  DV_phys_or_sex_partner_p  DM_age_mean  DM_age_marr_mean  \
# 0         Colombia                     34.24        29.43             19.32
# 1         Colombia                     43.26        29.78             20.13
# 2         Colombia                     39.72        30.05             20.48
# 3         Colombia                     49.00        29.48             19.68
# 4         Colombia                     42.68        30.10             20.89
# ...            ...                       ...          ...               ...
# 2251       Senegal                     21.19        27.52             18.29
# 2252  Sierra Leone                     38.76        29.29             18.30
# 2253  Sierra Leone                     59.93        28.82             18.84
# 2254  Sierra Leone                     40.98        29.31             19.15
# 2255  Sierra Leone                     59.51        27.56             19.80
#
#       ED_educ_years_mean  FF_TFR  principal component 1  \
# 0                   7.96   2.709               0.934209
# 1                   7.35   2.783               1.078247
# 2                   7.86   2.536               1.489480
# 3                   7.47   2.551               0.909939
# 4                   9.49   2.422               1.996145
# ...                  ...     ...                    ...
# 2251                4.35   5.318              -1.372330
# 2252                3.99   4.649              -1.063171
# 2253                3.56   4.460              -1.136629
# 2254                3.88   4.970              -0.888892
# 2255                7.24   2.931               0.357635
#
#       principal component 2  class
# 0                 -0.354148      2
# 1                 -0.809714      2
# 2                 -0.658216      2
# 3                 -1.132377      2
# 4                 -0.982361      2
# ...                     ...    ...
# 2251               0.909303      0
# 2252              -0.383649      1
# 2253              -1.425892      1
# 2254              -0.444863      1
# 2255              -1.368487      2
#
# [2256 rows x 9 columns]

# %%
country_demo = "CountryDemographics.csv"
country_demo_df = pd.read_csv(country_demo)
country_demo_df
# Out:
#      Unnamed: 0   country_name country_code   latitude   longitude  \
# 0             0        Austria           AT  47.516231   14.550072
# 1             1      Australia           AU -25.274398  133.775136
# 2             2     Bangladesh           BD  23.684994   90.356331
# 3             3        Belgium           BE  50.503887    4.469936
# 4             4   Burkina Faso           BF  12.238333   -1.561593
# ..          ...            ...          ...        ...         ...
# 315         315  United States           US  37.090240  -95.712891
# 316         316        Uruguay           UY -32.522779  -55.765835
# 317         317   South Africa           ZA -30.559482   22.937506
# 318         318         Zambia           ZM -13.133897   27.849332
# 319         319       Zimbabwe           ZW -19.015438   29.154857
#
#               GDP
# 0    3.711230e+11
# 1    1.058007e+12
# 2    1.645154e+11
# 3    4.491997e+11
# 4    1.044752e+10
# ..            ...
# 315  1.590805e+13
# 316  3.968593e+10
# 317  3.242687e+11
# 318  1.698932e+10
# 319  1.398755e+10
#
# [320 rows x 6 columns]

# %%
# combined_df = clustered_df


clustered_df = clustered_df.set_index('country_name')
country_demo_df = country_demo_df.set_index('country_name')
combined_df = clustered_df.join(country_demo_df,on = "country_name", how="left")

combined_df = combined_df.drop(columns= ['country_code','principal component 1','principal component 2','Unnamed: 0'])

# %%
combined_df
combined_df = combined_df.drop_duplicates()
combined_df
# Out:
#               DV_phys_or_sex_partner_p  DM_age_mean  DM_age_marr_mean  \
# country_name
# Colombia                         34.24        29.43             19.32
# Colombia                         43.26        29.78             20.13
# Colombia                         39.72        30.05             20.48
# Colombia                         49.00        29.48             19.68
# Colombia                         42.68        30.10             20.89
# ...                                ...          ...               ...
# Senegal                          21.19        27.52             18.29
# Sierra Leone                     38.76        29.29             18.30
# Sierra Leone                     59.93        28.82             18.84
# Sierra Leone                     40.98        29.31             19.15
# Sierra Leone                     59.51        27.56             19.80
#
#               ED_educ_years_mean  FF_TFR  class   latitude  longitude  \
# country_name
# Colombia                    7.96   2.709      2   4.570868 -74.297333
# Colombia                    7.35   2.783      2   4.570868 -74.297333
# Colombia                    7.86   2.536      2   4.570868 -74.297333
# Colombia                    7.47   2.551      2   4.570868 -74.297333
# Colombia                    9.49   2.422      2   4.570868 -74.297333
# ...                          ...     ...    ...        ...        ...
# Senegal                     4.35   5.318      0  14.497401 -14.452362
# Sierra Leone                3.99   4.649      1   8.460555 -11.779889
# Sierra Leone                3.56   4.460      1   8.460555 -11.779889
# Sierra Leone                3.88   4.970      1   8.460555 -11.779889
# Sierra Leone                7.24   2.931      2   8.460555 -11.779889
#
#                        GDP
# country_name
# Colombia      2.446231e+11
# Colombia      2.446231e+11
# Colombia      2.446231e+11
# Colombia      2.446231e+11
# Colombia      2.446231e+11
# ...                    ...
# Senegal       1.612874e+10
# Sierra Leone  2.891161e+09
# Sierra Leone  2.891161e+09
# Sierra Leone  2.891161e+09
# Sierra Leone  2.891161e+09
#
# [2184 rows x 9 columns]

# %%
combined_df.to_csv('Women_well_being_clustered_data.csv')
