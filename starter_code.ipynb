# %%
import pandas as pd
df = pd.DataFrame

# %%
data_file = "Resources/livwell_lin_interpolated.csv"
data_file_df = pd.read_csv(data_file)
data_file_df
# Out:
#       country_name country_code  year  region_num_harmonized  \
# 0         Colombia          COL  1990                      1
# 1         Colombia          COL  1990                      2
# 2         Colombia          COL  1990                      3
# 3         Colombia          COL  1990                      4
# 4         Colombia          COL  1990                      5
# ...            ...          ...   ...                    ...
# 7365       Senegal          SEN  2019                      4
# 7366  Sierra Leone          SLE  2019                      1
# 7367  Sierra Leone          SLE  2019                      2
# 7368  Sierra Leone          SLE  2019                      3
# 7369  Sierra Leone          SLE  2019                      4
#
#                     region_name_harmonized   SurveyId  interview_year_mean  \
# 0                                Atlantica  CO1990DHS               1990.0
# 1                                 Oriental  CO1990DHS               1990.0
# 2                                  Central  CO1990DHS               1990.0
# 3                                 Pacifica  CO1990DHS               1990.0
# 4                                   Bogota  CO1990DHS               1990.0
# ...                                    ...        ...                  ...
# 7365  Kolda + Ziguinchor + Sedhiou (South)  SN2019DHS               2019.0
# 7366                               Eastern  SL2019DHS               2019.0
# 7367              Northern + North Western  SL2019DHS               2019.0
# 7368                              Southern  SL2019DHS               2019.0
# 7369                               Western  SL2019DHS               2019.0
#
#       interview_month_mean  CMC_interview_mean  DM_age_15.19_p  ...  \
# 0                      7.0             1086.75           21.52  ...
# 1                      7.0             1086.93           22.84  ...
# 2                      7.0             1086.76           19.49  ...
# 3                      7.0             1086.59           21.86  ...
# 4                      5.0             1085.41           19.51  ...
# ...                    ...                 ...             ...  ...
# 7365                   8.0             1435.61           24.41  ...
# 7366                   7.0             1434.66           21.11  ...
# 7367                   7.0             1434.77           22.77  ...
# 7368                   7.0             1434.62           21.73  ...
# 7369                   6.0             1434.14           21.76  ...
#
#       EI_computer_p  EI_computer_p_se  DP_decide_no_contraception_p  \
# 0               NaN               NaN                           NaN
# 1               NaN               NaN                           NaN
# 2               NaN               NaN                           NaN
# 3               NaN               NaN                           NaN
# 4               NaN               NaN                           NaN
# ...             ...               ...                           ...
# 7365          10.67              2.09                         76.89
# 7366           2.06              0.34                         44.78
# 7367           2.36              0.30                         52.67
# 7368           2.33              0.36                         63.38
# 7369          14.71              1.37                         48.40
#
#       DP_decide_no_contraception_p_se  EI_internet_day_p  \
# 0                                 NaN                NaN
# 1                                 NaN                NaN
# 2                                 NaN                NaN
# 3                                 NaN                NaN
# 4                                 NaN                NaN
# ...                               ...                ...
# 7365                             2.18              13.12
# 7366                             2.50               3.01
# 7367                             2.31               3.43
# 7368                             2.04               5.50
# 7369                             3.45              20.95
#
#       EI_internet_day_p_se  EI_internet_week_p  EI_internet_week_p_se  \
# 0                      NaN                 NaN                    NaN
# 1                      NaN                 NaN                    NaN
# 2                      NaN                 NaN                    NaN
# 3                      NaN                 NaN                    NaN
# 4                      NaN                 NaN                    NaN
# ...                    ...                 ...                    ...
# 7365                  1.77               23.30                   2.13
# 7366                  0.50                5.56                   0.62
# 7367                  0.41                5.44                   0.54
# 7368                  0.50                7.19                   0.66
# 7369                  1.68               30.15                   1.96
#
#       EI_mobile_p  EI_mobile_p_se
# 0             NaN             NaN
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN
# ...           ...             ...
# 7365        55.54            2.54
# 7366        33.34            1.65
# 7367        34.53            1.36
# 7368        32.44            1.54
# 7369        70.46            1.44
#
# [7370 rows x 407 columns]

# %%
dv_df = data_file_df.loc[:, data_file_df.columns.str.startswith('DV_')]
dv_df.columns
# Out:
# Index(['DV_phys_12m_p', 'DV_phys_12m_p_se', 'DV_phys_or_sex_partner_12m_p',
#        'DV_phys_or_sex_partner_12m_p_se', 'DV_phys_or_sex_partner_p',
#        'DV_phys_or_sex_partner_p_se', 'DV_phys_p', 'DV_phys_p_se',
#        'DV_phys_partner_12m_p', 'DV_phys_partner_12m_p_se',
#        'DV_phys_partner_p', 'DV_phys_partner_p_se', 'DV_sex_12m_p',
#        'DV_sex_12m_p_se', 'DV_sex_p', 'DV_sex_p_se', 'DV_sex_partner_12m_p',
#        'DV_sex_partner_12m_p_se', 'DV_sex_partner_p', 'DV_sex_partner_p_se'],
#       dtype='object')

# %%
dv_df = data_file_df[['DV_phys_or_sex_partner_p','country_name','year']]
dv_df
# Out:
#       DV_phys_or_sex_partner_p  country_name  year
# 0                          NaN      Colombia  1990
# 1                          NaN      Colombia  1990
# 2                          NaN      Colombia  1990
# 3                          NaN      Colombia  1990
# 4                          NaN      Colombia  1990
# ...                        ...           ...   ...
# 7365                     21.19       Senegal  2019
# 7366                     38.76  Sierra Leone  2019
# 7367                     59.93  Sierra Leone  2019
# 7368                     40.98  Sierra Leone  2019
# 7369                     59.51  Sierra Leone  2019
#
# [7370 rows x 3 columns]

# %%
edu_df = data_file_df.loc[:, data_file_df.columns.str.startswith('ED_')]
edu_df.columns
# Out:
# Index(['ED_attainment_no_educ_p', 'ED_attainment_no_educ_p_se',
#        'ED_attainment_primary_completed_p',
#        'ED_attainment_primary_completed_p_se', 'ED_attainment_primary_p',
#        'ED_attainment_primary_p_se', 'ED_attainment_secondary_completed_p',
#        'ED_attainment_secondary_completed_p_se',
#        'ED_attainment_secondary_higher_p',
#        'ED_attainment_secondary_higher_p_se', 'ED_attainment_secondary_p',
#        'ED_attainment_secondary_p_se', 'ED_educ_years_mean',
#        'ED_educ_years_mean_se', 'ED_litt_p', 'ED_litt_p_se', 'ED_litt_whole_p',
#        'ED_litt_whole_p_se'],
#       dtype='object')

# %%
edu_df = data_file_df[['ED_attainment_no_educ_p',
       'ED_attainment_primary_completed_p',
        'ED_attainment_secondary_completed_p',
       'ED_attainment_secondary_higher_p','country_name']]
edu_df
# Out:
#       ED_attainment_no_educ_p  ED_attainment_primary_completed_p  \
# 0                        7.34                              17.55
# 1                        4.58                              20.74
# 2                        3.63                              19.48
# 3                        3.49                              17.06
# 4                        1.57                              13.60
# ...                       ...                                ...
# 7365                    43.10                               7.06
# 7366                    49.66                               4.07
# 7367                    54.88                               3.21
# 7368                    49.00                               4.72
# 7369                    24.87                               2.96
#
#       ED_attainment_secondary_completed_p  ED_attainment_secondary_higher_p  \
# 0                                   11.35                             50.25
# 1                                    9.68                             48.53
# 2                                   13.73                             50.19
# 3                                   10.94                             50.84
# 4                                   21.18                             75.36
# ...                                   ...                               ...
# 7365                                 1.18                             35.29
# 7366                                 4.14                             35.83
# 7367                                 3.65                             32.17
# 7368                                 3.78                             33.48
# 7369                                10.34                             64.70
#
#       country_name
# 0         Colombia
# 1         Colombia
# 2         Colombia
# 3         Colombia
# 4         Colombia
# ...            ...
# 7365       Senegal
# 7366  Sierra Leone
# 7367  Sierra Leone
# 7368  Sierra Leone
# 7369  Sierra Leone
#
# [7370 rows x 5 columns]

# %%
dv_edu_df = data_file_df[['ED_attainment_no_educ_p',
       'ED_attainment_primary_completed_p',
        'ED_attainment_secondary_completed_p',
       'ED_attainment_secondary_higher_completed_p','country_name', 'DV_phys_or_sex_partner_p','year']]
dv_edu_df
# Out:
#       ED_attainment_no_educ_p  ED_attainment_primary_completed_p  \
# 0                        7.34                              17.55
# 1                        4.58                              20.74
# 2                        3.63                              19.48
# 3                        3.49                              17.06
# 4                        1.57                              13.60
# ...                       ...                                ...
# 7365                    43.10                               7.06
# 7366                    49.66                               4.07
# 7367                    54.88                               3.21
# 7368                    49.00                               4.72
# 7369                    24.87                               2.96
#
#       ED_attainment_secondary_completed_p  ED_attainment_secondary_higher_p  \
# 0                                   11.35                             50.25
# 1                                    9.68                             48.53
# 2                                   13.73                             50.19
# 3                                   10.94                             50.84
# 4                                   21.18                             75.36
# ...                                   ...                               ...
# 7365                                 1.18                             35.29
# 7366                                 4.14                             35.83
# 7367                                 3.65                             32.17
# 7368                                 3.78                             33.48
# 7369                                10.34                             64.70
#
#       country_name  DV_phys_or_sex_partner_p  year
# 0         Colombia                       NaN  1990
# 1         Colombia                       NaN  1990
# 2         Colombia                       NaN  1990
# 3         Colombia                       NaN  1990
# 4         Colombia                       NaN  1990
# ...            ...                       ...   ...
# 7365       Senegal                     21.19  2019
# 7366  Sierra Leone                     38.76  2019
# 7367  Sierra Leone                     59.93  2019
# 7368  Sierra Leone                     40.98  2019
# 7369  Sierra Leone                     59.51  2019
#
# [7370 rows x 7 columns]

# %%
dv_edu_df.groupby('country_name')

# %%
dv_edu_df = dv_edu_df.groupby('country_name')

# %%
clean_dv_edu = dv_edu_df.first()

# %%
clean_dv_edu
# Out:
#                            ED_attainment_no_educ_p  \
# country_name
# Armenia                                       0.21
# Bangladesh                                   29.50
# Benin                                        81.14
# Bolivia                                      16.75
# Burkina Faso                                 83.71
# Burundi                                      10.97
# Cambodia                                     44.10
# Cameroon                                      1.80
# Colombia                                      7.34
# Congo Democratic Republic                     0.95
# Cote d'Ivoire                                62.84
# Egypt                                        18.51
# Ethiopia                                     77.83
# Gabon                                         5.98
# Ghana                                        27.39
# Guatemala                                    13.90
# Guinea                                       82.00
# Haiti                                        17.24
# Honduras                                      3.68
# India                                        51.85
# Indonesia                                     4.42
# Jordan                                        3.81
# Kenya                                         7.63
# Lesotho                                       1.72
# Liberia                                      30.14
# Madagascar                                    6.84
# Malawi                                       20.19
# Maldives                                      7.50
# Mali                                         83.47
# Morocco                                      81.18
# Mozambique                                   54.21
# Namibia                                      10.30
# Nepal                                        59.90
# Nicaragua                                    20.41
# Niger                                        92.75
# Nigeria                                      35.92
# Pakistan                                     56.32
# Peru                                          8.28
# Philippines                                   0.80
# Rwanda                                       11.74
# Senegal                                      53.70
# Sierra Leone                                 70.83
# South Africa                                  1.98
# Tajikistan                                    0.90
# Tanzania                                     30.48
# Timor-Leste                                  31.40
# Togo                                         25.33
# Turkey                                        7.17
# Uganda                                       14.36
# Vietnam                                       4.38
# Zambia                                       15.66
# Zimbabwe                                     14.44
#
#                            ED_attainment_primary_completed_p  \
# country_name
# Armenia                                                 0.41
# Bangladesh                                             13.81
# Benin                                                   1.16
# Bolivia                                                 3.54
# Burkina Faso                                            5.13
# Burundi                                                13.75
# Cambodia                                                4.70
# Cameroon                                               19.31
# Colombia                                               17.55
# Congo Democratic Republic                               4.33
# Cote d'Ivoire                                           7.70
# Egypt                                                   5.11
# Ethiopia                                                2.31
# Gabon                                                   4.75
# Ghana                                                  46.98
# Guatemala                                              15.75
# Guinea                                                  1.11
# Haiti                                                   6.15
# Honduras                                               31.95
# India                                                   3.05
# Indonesia                                              16.79
# Jordan                                                  3.31
# Kenya                                                  24.52
# Lesotho                                                28.98
# Liberia                                                 6.56
# Madagascar                                              4.38
# Malawi                                                 15.82
# Maldives                                               10.85
# Mali                                                    0.64
# Morocco                                                 3.72
# Mozambique                                              1.32
# Namibia                                                19.45
# Nepal                                                   1.71
# Nicaragua                                              16.64
# Niger                                                   0.35
# Nigeria                                                17.56
# Pakistan                                                5.20
# Peru                                                   28.49
# Philippines                                            11.69
# Rwanda                                                 19.31
# Senegal                                                15.35
# Sierra Leone                                            3.79
# South Africa                                            9.19
# Tajikistan                                              1.57
# Tanzania                                               48.57
# Timor-Leste                                             9.63
# Togo                                                    5.02
# Turkey                                                 38.84
# Uganda                                                 11.44
# Vietnam                                                 6.35
# Zambia                                                 28.83
# Zimbabwe                                               23.62
#
#                            ED_attainment_secondary_completed_p  \
# country_name
# Armenia                                                  73.14
# Bangladesh                                                2.35
# Benin                                                     0.09
# Bolivia                                                   7.09
# Burkina Faso                                              0.43
# Burundi                                                   1.66
# Cambodia                                                  0.67
# Cameroon                                                  2.45
# Colombia                                                 11.35
# Congo Democratic Republic                                15.93
# Cote d'Ivoire                                             0.29
# Egypt                                                    15.58
# Ethiopia                                                  1.18
# Gabon                                                     2.91
# Ghana                                                     2.26
# Guatemala                                                 8.29
# Guinea                                                    0.39
# Haiti                                                     1.75
# Honduras                                                 11.45
# India                                                     0.38
# Indonesia                                                12.46
# Jordan                                                   13.40
# Kenya                                                     9.81
# Lesotho                                                   6.11
# Liberia                                                  11.03
# Madagascar                                                1.72
# Malawi                                                    1.92
# Maldives                                                  2.03
# Mali                                                      0.12
# Morocco                                                   1.05
# Mozambique                                                0.12
# Namibia                                                   6.74
# Nepal                                                     1.28
# Nicaragua                                                11.72
# Niger                                                     0.11
# Nigeria                                                   9.36
# Pakistan                                                  1.07
# Peru                                                      7.73
# Philippines                                              30.12
# Rwanda                                                    8.31
# Senegal                                                   3.87
# Sierra Leone                                              0.54
# South Africa                                             18.29
# Tajikistan                                               32.79
# Tanzania                                                  0.00
# Timor-Leste                                              10.29
# Togo                                                      3.07
# Turkey                                                    8.84
# Uganda                                                    9.81
# Vietnam                                                   7.28
# Zambia                                                    2.28
# Zimbabwe                                                  0.18
#
#                            ED_attainment_secondary_higher_p  \
# country_name
# Armenia                                               98.76
# Bangladesh                                            16.47
# Benin                                                  5.08
# Bolivia                                               46.91
# Burkina Faso                                           4.95
# Burundi                                               52.54
# Cambodia                                              14.00
# Cameroon                                              63.45
# Colombia                                              50.25
# Congo Democratic Republic                             85.08
# Cote d'Ivoire                                         12.12
# Egypt                                                 29.29
# Ethiopia                                               6.78
# Gabon                                                 69.55
# Ghana                                                  9.55
# Guatemala                                             43.86
# Guinea                                                 7.80
# Haiti                                                 42.84
# Honduras                                              41.92
# India                                                 10.89
# Indonesia                                             27.97
# Jordan                                                42.58
# Kenya                                                 47.96
# Lesotho                                               40.96
# Liberia                                               39.54
# Madagascar                                            36.53
# Malawi                                                 7.93
# Maldives                                              36.03
# Mali                                                   3.50
# Morocco                                                8.02
# Mozambique                                             2.05
# Namibia                                               52.16
# Nepal                                                  9.06
# Nicaragua                                             32.27
# Niger                                                  2.01
# Nigeria                                               34.07
# Pakistan                                               9.75
# Peru                                                  35.28
# Philippines                                           82.47
# Rwanda                                                33.56
# Senegal                                               20.34
# Sierra Leone                                          13.58
# South Africa                                          75.06
# Tajikistan                                            95.34
# Tanzania                                               4.44
# Timor-Leste                                           43.64
# Togo                                                  36.02
# Turkey                                                24.48
# Uganda                                                23.64
# Vietnam                                               46.10
# Zambia                                                21.22
# Zimbabwe                                              33.00
#
#                            DV_phys_or_sex_partner_p  year
# country_name
# Armenia                                       28.23  2000
# Bangladesh                                    49.57  1994
# Benin                                         24.22  1996
# Bolivia                                         NaN  1998
# Burkina Faso                                  17.08  2003
# Burundi                                       27.03  2010
# Cambodia                                      12.29  2000
# Cameroon                                      47.72  2004
# Colombia                                      34.24  1990
# Congo Democratic Republic                     56.63  2007
# Cote d'Ivoire                                 20.42  1994
# Egypt                                         14.07  1992
# Ethiopia                                      24.66  2000
# Gabon                                         46.75  2000
# Ghana                                         15.12  1993
# Guatemala                                     20.60  1995
# Guinea                                          NaN  2005
# Haiti                                         24.88  2000
# Honduras                                      20.72  2005
# India                                         35.36  1993
# Indonesia                                       NaN  1994
# Jordan                                        12.89  1997
# Kenya                                         31.38  1993
# Lesotho                                         NaN  2004
# Liberia                                       38.86  2007
# Madagascar                                      NaN  1992
# Malawi                                        27.60  1992
# Maldives                                      11.55  2009
# Mali                                          32.48  1996
# Morocco                                         NaN  1992
# Mozambique                                    17.02  1997
# Namibia                                       32.26  2000
# Nepal                                           NaN  1996
# Nicaragua                                       NaN  1998
# Niger                                           NaN  1992
# Nigeria                                       26.01  2003
# Pakistan                                      17.30  1991
# Peru                                          40.95  1996
# Philippines                                   18.78  2003
# Rwanda                                        46.33  2008
# Senegal                                       20.98  1993
# Sierra Leone                                  39.79  2008
# South Africa                                  18.12  1998
# Tajikistan                                    14.84  2012
# Tanzania                                      69.06  1996
# Timor-Leste                                   22.51  2009
# Togo                                          18.67  1998
# Turkey                                          NaN  2003
# Uganda                                        47.78  1995
# Vietnam                                         NaN  1997
# Zambia                                        45.38  1992
# Zimbabwe                                      30.32  1994

# %%
#clean_dv_edu.to_csv('dv_edu.csv', header=False, index=False)
clean_dv_edu.to_csv('dv_edu.csv', index=False)
