# %%
import pandas as pd

# %%
data_file = "Resources/livwell_lin_interpolated.csv"
data_file_df = pd.read_csv(data_file)
data_file_df
# Out:
#       country_name country_code  year  region_num_harmonized  \
# 0         Colombia          COL  1990                      1
# 1         Colombia          COL  1990                      2
# 2         Colombia          COL  1990                      3
# 3         Colombia          COL  1990                      4
# 4         Colombia          COL  1990                      5
# ...            ...          ...   ...                    ...
# 7365       Senegal          SEN  2019                      4
# 7366  Sierra Leone          SLE  2019                      1
# 7367  Sierra Leone          SLE  2019                      2
# 7368  Sierra Leone          SLE  2019                      3
# 7369  Sierra Leone          SLE  2019                      4
#
#                     region_name_harmonized   SurveyId  interview_year_mean  \
# 0                                Atlantica  CO1990DHS               1990.0
# 1                                 Oriental  CO1990DHS               1990.0
# ...

# %%
repro_health_df = data_file_df.loc[:, data_file_df.columns.str.startswith('RH_')]
repro_health_df.columns
# Out:
# Index(['RH_age_first_birth_mean', 'RH_age_first_birth_mean_se',
#        'RH_age_first_sex_mean', 'RH_age_first_sex_mean_se',
#        'RH_children_born_mean', 'RH_children_born_mean_se',
#        'RH_children_living_mean', 'RH_children_living_mean_se',
#        'RH_contr_modern_know_p', 'RH_contr_modern_know_p_se',
#        'RH_contr_modern_p', 'RH_contr_modern_p_se', 'RH_contr_p',
#        'RH_contr_p_se', 'RH_family_planning_mobile_p',
#        'RH_family_planning_mobile_p_se', 'RH_family_planning_radio_p',
#        'RH_family_planning_radio_p_se', 'RH_family_planning_tv_p',
#        'RH_family_planning_tv_p_se', 'RH_family_planning_news_p',
#        'RH_family_planning_news_p_se'],
#       dtype='object')

# %%
repro_health_df = data_file_df[['RH_age_first_birth_mean', 'RH_age_first_birth_mean_se',
       'RH_age_first_sex_mean', 'RH_age_first_sex_mean_se',
       'RH_children_born_mean', 'RH_children_born_mean_se',
       'RH_children_living_mean', 'RH_children_living_mean_se',
       'RH_contr_modern_know_p', 'RH_contr_modern_know_p_se',
       'RH_contr_modern_p', 'RH_contr_modern_p_se', 'RH_contr_p',
       'RH_contr_p_se', 'RH_family_planning_mobile_p',
       'RH_family_planning_mobile_p_se', 'RH_family_planning_radio_p',
       'RH_family_planning_radio_p_se', 'RH_family_planning_tv_p',
       'RH_family_planning_tv_p_se', 'RH_family_planning_news_p',
       'RH_family_planning_news_p_se','country_name']]
repro_health_df.set_index('country_name', inplace=True)
repro_health_df
# Out:
#               RH_age_first_birth_mean  RH_age_first_birth_mean_se  \
# country_name
# Colombia                        20.48                        0.15
# Colombia                        21.52                        0.28
# Colombia                        21.20                        0.18
# Colombia                        21.26                        0.28
# Colombia                        22.22                        0.17
# ...                               ...                         ...
# Senegal                         19.74                        0.16
# Sierra Leone                    19.16                        0.13
# Sierra Leone                    19.51                        0.11
# Sierra Leone                    19.44                        0.13
# Sierra Leone                    19.78                        0.14
#
#               RH_age_first_sex_mean  RH_age_first_sex_mean_se  \
# country_name
# Colombia                      18.53                      0.16
# ...

# %%
fertility_df = data_file_df.loc[:, data_file_df.columns.str.startswith('FF_')]
fertility_df.columns
# Out:
# Index(['FF_ASFR_15.19', 'FF_ASFR_20.24', 'FF_ASFR_25.29', 'FF_ASFR_30.34',
#        'FF_ASFR_35.39', 'FF_ASFR_40.44', 'FF_ASFR_45.49', 'FF_ASFR_SE_15.19',
#        'FF_ASFR_SE_20.24', 'FF_ASFR_SE_25.29', 'FF_ASFR_SE_30.34',
#        'FF_ASFR_SE_35.39', 'FF_ASFR_SE_40.44', 'FF_ASFR_SE_45.49', 'FF_GFR',
#        'FF_GFR_SE', 'FF_TFR', 'FF_TFR_SE'],
#       dtype='object')

# %%
fertility_df = data_file_df[['FF_ASFR_15.19', 'FF_ASFR_20.24', 'FF_ASFR_25.29', 'FF_ASFR_30.34',
       'FF_ASFR_35.39', 'FF_ASFR_40.44', 'FF_ASFR_45.49', 'FF_ASFR_SE_15.19',
       'FF_ASFR_SE_20.24', 'FF_ASFR_SE_25.29', 'FF_ASFR_SE_30.34',
       'FF_ASFR_SE_35.39', 'FF_ASFR_SE_40.44', 'FF_ASFR_SE_45.49', 'FF_GFR',
       'FF_GFR_SE', 'FF_TFR', 'FF_TFR_SE','country_name']]
fertility_df.set_index('country_name', inplace=True)
fertility_df
# Out:
#               FF_ASFR_15.19  FF_ASFR_20.24  FF_ASFR_25.29  FF_ASFR_30.34  \
# country_name
# Colombia             89.525        195.969        180.204        134.492
# Colombia             47.245        204.926        147.721         65.814
# Colombia             61.827        150.545        126.903         84.533
# Colombia            100.075        165.222        142.106         95.463
# Colombia             42.887        121.272        147.191        104.688
# ...                     ...            ...            ...            ...
# Senegal             106.033        219.916        242.824        214.255
# Sierra Leone        112.600        227.526        205.471        180.421
# Sierra Leone        108.894        206.340        190.118        170.187
# Sierra Leone        133.052        235.986        221.269        191.893
# Sierra Leone         60.004        146.192        153.616        115.702
#
# ...

# %%
child_mort_df = data_file_df[["HL_IMR","HL_CMR","HL_U5MR","HL_NNMR","HL_PNNMR","country_name"]]
child_mort_df.columns
# Out:
# Index(['HL_IMR', 'HL_CMR', 'HL_U5MR', 'HL_NNMR', 'HL_PNNMR', 'country_name'], dtype='object')

# %%
child_mort_df
# Out:
#       HL_IMR  HL_CMR  HL_U5MR  HL_NNMR  HL_PNNMR  country_name
# 0      19.51    9.52    28.85    11.98      7.53      Colombia
# 1      13.25    7.99    21.13    10.86      2.38      Colombia
# 2      15.86    4.99    20.77    10.26      5.60      Colombia
# 3      17.50    2.43    19.88     6.74     10.76      Colombia
# 4      15.58    4.85    20.36    10.47      5.11      Colombia
# ...      ...     ...      ...      ...       ...           ...
# 7365   40.53   20.26    59.97    23.32     17.21       Senegal
# 7366   73.30   47.66   117.47    31.35     41.95  Sierra Leone
# 7367   79.71   53.59   129.02    31.95     47.76  Sierra Leone
# 7368   78.89   46.11   121.36    23.42     55.47  Sierra Leone
# 7369   64.80   51.92   113.35    34.96     29.84  Sierra Leone
#
# [7370 rows x 6 columns]

# %%
dom_vio_df = data_file_df.loc[:, data_file_df.columns.str.startswith('DV_')]
dom_vio_df.columns
# Out:
# Index(['DV_phys_12m_p', 'DV_phys_12m_p_se', 'DV_phys_or_sex_partner_12m_p',
#        'DV_phys_or_sex_partner_12m_p_se', 'DV_phys_or_sex_partner_p',
#        'DV_phys_or_sex_partner_p_se', 'DV_phys_p', 'DV_phys_p_se',
#        'DV_phys_partner_12m_p', 'DV_phys_partner_12m_p_se',
#        'DV_phys_partner_p', 'DV_phys_partner_p_se', 'DV_sex_12m_p',
#        'DV_sex_12m_p_se', 'DV_sex_p', 'DV_sex_p_se', 'DV_sex_partner_12m_p',
#        'DV_sex_partner_12m_p_se', 'DV_sex_partner_p', 'DV_sex_partner_p_se'],
#       dtype='object')

# %%
dom_vio_df = data_file_df[['DV_phys_12m_p', 'DV_phys_12m_p_se', 'DV_phys_or_sex_partner_12m_p',
       'DV_phys_or_sex_partner_12m_p_se', 'DV_phys_or_sex_partner_p',
       'DV_phys_or_sex_partner_p_se', 'DV_phys_p', 'DV_phys_p_se',
       'DV_phys_partner_12m_p', 'DV_phys_partner_12m_p_se',
       'DV_phys_partner_p', 'DV_phys_partner_p_se', 'DV_sex_12m_p',
       'DV_sex_12m_p_se', 'DV_sex_p', 'DV_sex_p_se', 'DV_sex_partner_12m_p',
       'DV_sex_partner_12m_p_se', 'DV_sex_partner_p', 'DV_sex_partner_p_se','country_name']]
dom_vio_df.set_index('country_name', inplace=True)
dom_vio_df
# Out:
#               DV_phys_12m_p  DV_phys_12m_p_se  DV_phys_or_sex_partner_12m_p  \
# country_name
# Colombia                NaN               NaN                           NaN
# Colombia                NaN               NaN                           NaN
# Colombia                NaN               NaN                           NaN
# Colombia                NaN               NaN                           NaN
# Colombia                NaN               NaN                           NaN
# ...                     ...               ...                           ...
# Senegal                7.44              1.38                          6.55
# Sierra Leone          38.27              2.63                         28.42
# Sierra Leone          45.10              1.99                         46.65
# Sierra Leone          37.84              1.75                         29.17
# Sierra Leone          47.44              3.03                         48.89
#
# ...

# %%
energy_df = data_file_df.loc[:, data_file_df.columns.str.startswith('EI_')]
energy_df.columns
# Out:
# Index(['EI_elec_p', 'EI_elec_p_se', 'EI_fridge_p', 'EI_fridge_p_se',
#        'EI_radio_p', 'EI_radio_p_se', 'EI_tv_p', 'EI_tv_p_se',
#        'EI_women_elec_p', 'EI_women_elec_p_se', 'EI_women_fridge_p',
#        'EI_women_fridge_p_se', 'EI_women_radio_p', 'EI_women_radio_p_se',
#        'EI_women_tv_p', 'EI_women_tv_p_se', 'EI_telephone_p',
#        'EI_telephone_p_se', 'EI_women_telephone_p', 'EI_women_telephone_p_se',
#        'EI_modern_cooking_p', 'EI_modern_cooking_p_se', 'EI_news_week_p',
#        'EI_news_week_p_se', 'EI_radio_week_p', 'EI_radio_week_p_se',
#        'EI_tv_week_p', 'EI_tv_week_p_se', 'EI_women_modern_cooking_p',
#        'EI_women_modern_cooking_p_se', 'EI_computer_p', 'EI_computer_p_se',
#        'EI_internet_day_p', 'EI_internet_day_p_se', 'EI_internet_week_p',
#        'EI_internet_week_p_se', 'EI_mobile_p', 'EI_mobile_p_se'],
#       dtype='object')

# %%
energy_df = data_file_df[['EI_elec_p', 'EI_elec_p_se', 'EI_fridge_p', 'EI_fridge_p_se',
       'EI_radio_p', 'EI_radio_p_se', 'EI_tv_p', 'EI_tv_p_se',
       'EI_women_elec_p', 'EI_women_elec_p_se', 'EI_women_fridge_p',
       'EI_women_fridge_p_se', 'EI_women_radio_p', 'EI_women_radio_p_se',
       'EI_women_tv_p', 'EI_women_tv_p_se', 'EI_telephone_p',
       'EI_telephone_p_se', 'EI_women_telephone_p', 'EI_women_telephone_p_se',
       'EI_modern_cooking_p', 'EI_modern_cooking_p_se', 'EI_news_week_p',
       'EI_news_week_p_se', 'EI_radio_week_p', 'EI_radio_week_p_se',
       'EI_tv_week_p', 'EI_tv_week_p_se', 'EI_women_modern_cooking_p',
       'EI_women_modern_cooking_p_se', 'EI_computer_p', 'EI_computer_p_se',
       'EI_internet_day_p', 'EI_internet_day_p_se', 'EI_internet_week_p',
       'EI_internet_week_p_se', 'EI_mobile_p', 'EI_mobile_p_se','country_name']]
energy_df.set_index('country_name', inplace=True)
energy_df
# Out:
#               EI_elec_p  EI_elec_p_se  EI_fridge_p  EI_fridge_p_se  \
# country_name
# Colombia          80.97          2.83        43.21            2.08
# Colombia          89.03          2.50        44.44            4.16
# Colombia          89.46          3.34        55.95            2.60
# Colombia          90.98          1.69        51.08            3.58
# Colombia          99.56          0.19        65.02            2.35
# ...                 ...           ...          ...             ...
# Senegal           47.90          4.05        17.05            2.06
# Sierra Leone       9.82          1.59         4.43            0.91
# Sierra Leone      11.33          1.10         5.09            0.54
# Sierra Leone       7.47          0.83         4.34            0.51
# Sierra Leone      64.24          2.88        36.75            2.23
#
#               EI_radio_p  EI_radio_p_se  EI_tv_p  EI_tv_p_se  EI_women_elec_p  \
# country_name
# ...

# %%
energy_avg = energy_df[['EI_elec_p', 'EI_elec_p_se', 'EI_fridge_p', 'EI_fridge_p_se',
       'EI_radio_p', 'EI_radio_p_se', 'EI_tv_p', 'EI_tv_p_se',
       'EI_women_elec_p', 'EI_women_elec_p_se', 'EI_women_fridge_p',
       'EI_women_fridge_p_se', 'EI_women_radio_p', 'EI_women_radio_p_se',
       'EI_women_tv_p', 'EI_women_tv_p_se', 'EI_telephone_p',
       'EI_telephone_p_se', 'EI_women_telephone_p', 'EI_women_telephone_p_se',
       'EI_modern_cooking_p', 'EI_modern_cooking_p_se', 'EI_news_week_p',
       'EI_news_week_p_se', 'EI_radio_week_p', 'EI_radio_week_p_se',
       'EI_tv_week_p', 'EI_tv_week_p_se', 'EI_women_modern_cooking_p',
       'EI_women_modern_cooking_p_se', 'EI_computer_p', 'EI_computer_p_se',
       'EI_internet_day_p', 'EI_internet_day_p_se', 'EI_internet_week_p',
       'EI_internet_week_p_se', 'EI_mobile_p', 'EI_mobile_p_se']].mean(axis=1)

# %%
energy_avg
# Out:
# country_name
# Colombia        34.265625
# Colombia        38.005625
# Colombia        40.874375
# Colombia        39.861250
# Colombia        45.146875
#                   ...
# Senegal         15.115526
# Sierra Leone     6.508684
# Sierra Leone     6.668684
# Sierra Leone     6.475000
# Sierra Leone    19.305263
# Length: 7370, dtype: float64

# %%
df = data_file_df[['EI_elec_p', 'EI_elec_p_se', 'EI_fridge_p', 'EI_fridge_p_se',
       'EI_radio_p', 'EI_radio_p_se', 'EI_tv_p', 'EI_tv_p_se',
       'EI_women_elec_p', 'EI_women_elec_p_se', 'EI_women_fridge_p',
       'EI_women_fridge_p_se', 'EI_women_radio_p', 'EI_women_radio_p_se',
       'EI_women_tv_p', 'EI_women_tv_p_se', 'EI_telephone_p',
       'EI_telephone_p_se', 'EI_women_telephone_p', 'EI_women_telephone_p_se',
       'EI_modern_cooking_p', 'EI_modern_cooking_p_se', 'EI_news_week_p',
       'EI_news_week_p_se', 'EI_radio_week_p', 'EI_radio_week_p_se',
       'EI_tv_week_p', 'EI_tv_week_p_se', 'EI_women_modern_cooking_p',
       'EI_women_modern_cooking_p_se', 'EI_computer_p', 'EI_computer_p_se',
       'EI_internet_day_p', 'EI_internet_day_p_se', 'EI_internet_week_p',
       'EI_internet_week_p_se', 'EI_mobile_p', 'EI_mobile_p_se',
                   'country_name', 
                   'DV_phys_12m_p', 'DV_phys_12m_p_se', 'DV_phys_or_sex_partner_12m_p',
       'DV_phys_or_sex_partner_12m_p_se', 'DV_phys_or_sex_partner_p',
       'DV_phys_or_sex_partner_p_se', 'DV_phys_p', 'DV_phys_p_se',
       'DV_phys_partner_12m_p', 'DV_phys_partner_12m_p_se',
       'DV_phys_partner_p', 'DV_phys_partner_p_se', 'DV_sex_12m_p',
       'DV_sex_12m_p_se', 'DV_sex_p', 'DV_sex_p_se', 'DV_sex_partner_12m_p',
       'DV_sex_partner_12m_p_se', 'DV_sex_partner_p', 'DV_sex_partner_p_se', 
                   "HL_IMR","HL_CMR","HL_U5MR","HL_NNMR","HL_PNNMR",
                   'FF_ASFR_15.19', 'FF_ASFR_20.24', 'FF_ASFR_25.29', 'FF_ASFR_30.34',
       'FF_ASFR_35.39', 'FF_ASFR_40.44', 'FF_ASFR_45.49', 'FF_ASFR_SE_15.19',
       'FF_ASFR_SE_20.24', 'FF_ASFR_SE_25.29', 'FF_ASFR_SE_30.34',
       'FF_ASFR_SE_35.39', 'FF_ASFR_SE_40.44', 'FF_ASFR_SE_45.49', 'FF_GFR',
        'FF_GFR_SE', 'FF_TFR', 'FF_TFR_SE',
                   'RH_age_first_birth_mean', 'RH_age_first_birth_mean_se',
       'RH_age_first_sex_mean', 'RH_age_first_sex_mean_se',
       'RH_children_born_mean', 'RH_children_born_mean_se',
       'RH_children_living_mean', 'RH_children_living_mean_se',
       'RH_contr_modern_know_p', 'RH_contr_modern_know_p_se',
       'RH_contr_modern_p', 'RH_contr_modern_p_se', 'RH_contr_p',
       'RH_contr_p_se', 'RH_family_planning_mobile_p',
       'RH_family_planning_mobile_p_se', 'RH_family_planning_radio_p',
       'RH_family_planning_radio_p_se', 'RH_family_planning_tv_p',
       'RH_family_planning_tv_p_se', 'RH_family_planning_news_p',
       'RH_family_planning_news_p_se']]

# %%
df
# Out:
#       EI_elec_p  EI_elec_p_se  EI_fridge_p  EI_fridge_p_se  EI_radio_p  \
# 0         80.97          2.83        43.21            2.08       66.81
# 1         89.03          2.50        44.44            4.16       85.50
# 2         89.46          3.34        55.95            2.60       86.35
# 3         90.98          1.69        51.08            3.58       85.94
# 4         99.56          0.19        65.02            2.35       95.80
# ...         ...           ...          ...             ...         ...
# 7365      47.90          4.05        17.05            2.06       55.88
# 7366       9.82          1.59         4.43            0.91       51.16
# 7367      11.33          1.10         5.09            0.54       48.20
# 7368       7.47          0.83         4.34            0.51       51.73
# 7369      64.24          2.88        36.75            2.23       72.43
#
#       EI_radio_p_se  EI_tv_p  EI_tv_p_se  EI_women_elec_p  EI_women_elec_p_se  \
# ...

# %%
df.count()
# Out:
# EI_elec_p                        7188
# EI_elec_p_se                     7188
# EI_fridge_p                      7164
# EI_fridge_p_se                   7164
# EI_radio_p                       7315
#                                  ...
# RH_family_planning_radio_p_se    6658
# RH_family_planning_tv_p          6610
# RH_family_planning_tv_p_se       6658
# RH_family_planning_news_p        6391
# RH_family_planning_news_p_se     6439
# Length: 104, dtype: int64

# %%
df=df.dropna(how="any")
df.count()
# Out:
# EI_elec_p                        158
# EI_elec_p_se                     158
# EI_fridge_p                      158
# EI_fridge_p_se                   158
# EI_radio_p                       158
#                                 ...
# RH_family_planning_radio_p_se    158
# RH_family_planning_tv_p          158
# RH_family_planning_tv_p_se       158
# RH_family_planning_news_p        158
# RH_family_planning_news_p_se     158
# Length: 104, dtype: int64

# %%
df.set_index('country_name', inplace=True)

# %%
df
# Out:
#               EI_elec_p  EI_elec_p_se  EI_fridge_p  EI_fridge_p_se  \
# country_name
# Malawi            12.48          1.27         6.91            1.21
# Malawi             8.87          1.11         6.08            1.04
# Malawi            12.01          0.79         5.79            0.47
# Zimbabwe          18.53          2.67        11.56            1.61
# Zimbabwe          12.28          2.63         8.16            1.46
# ...                 ...           ...          ...             ...
# Senegal           47.90          4.05        17.05            2.06
# Sierra Leone       9.82          1.59         4.43            0.91
# Sierra Leone      11.33          1.10         5.09            0.54
# Sierra Leone       7.47          0.83         4.34            0.51
# Sierra Leone      64.24          2.88        36.75            2.23
#
#               EI_radio_p  EI_radio_p_se  EI_tv_p  EI_tv_p_se  EI_women_elec_p  \
# country_name
# ...
